# %%
import os
import main

# %%
main.file_open()
# Out:
# {'playlists': [{'name': 'B3w1ld3rm3nT',
#    'lastModifiedDate': '2023-08-31',
#    'items': [{'track': {'trackName': 'Give A Chance - Original Mix',
#       'artistName': 'Lombard Street',
#       'albumName': 'The Murder Track',
#       'trackUri': 'spotify:track:616Iwt8QPF4RwhFblJp8wo'},
#      'episode': None,
#      'localTrack': None,
#      'addedDate': '2023-08-29'},
#     {'track': {'trackName': 'Got To Know',
#       'artistName': 'T.Markakis',
#       'albumName': 'Got To Know',
#       'trackUri': 'spotify:track:0KUKGZ7PJfbtmBbwtWcK0j'},
#      'episode': None,
#      'localTrack': None,
#      'addedDate': '2023-08-30'},
#     {'track': {'trackName': 'Got To Know - Sebas Ramis Remix',
#       'artistName': 'T.Markakis',
#       'albumName': 'Got To Know',
#       'trackUri': 'spotify:track:2aLuy3C5UlbVMO0lHsCgxZ'},
#      'episode': None,
#      'localTrack': None,
#      'addedDate': '2023-08-30'},
# ...

# %%
main.data_parse()
# Out:
# {'B3w1ld3rm3nT': ['Give A Chance - Original Mix',
#   'Got To Know',
#   'Got To Know - Sebas Ramis Remix',
#   'Got To Know - J.M.Aboga, Delagarza Remix',
#   'Honey',
#   'Honey - Extended Mix',
#   'The Mission',
#   'NY Strut',
#   'Carry On - Edit',
#   'Jazz Stories - Original Mix',
#   'For The Culture - Radio Edit',
#   "Running Out - Angelo Ferreri 'Glitter' Mix - Radio Edit"],
#  'My recommendation playlist': ['Paris',
#   "Air 'Em Out",
#   'Guess What Bitch, We Back Hoe!',
#   'HOT!',
#   'Story 2',
#   'Purple Nights',
#   'Life Lessons (feat. Headie One)',
#   'Tougher Colder Killer (feat. Killer Mike & Despot)',
#   'Jack Harlow Combo Meal',
#   'Post Verified Lifestyle'],
#  'HYP3. Brought you by Kyle and Agastya': ['BALD!',
#   'Lean Beef Patty',
#   'Burfict!',
#   'Steppa Pig',
#   'God Loves You',
#   'Fentanyl Tester',
#   'Run The Jewels',
#   'Orange Juice Jones',
#   'Two Tens (feat. Anderson .Paak)',
#   'Too Fast (Pull Over) (with Anderson .Paak & Latto)',
# ...

# %%
main.playlist_request("Here in Seattle ")
# Out:
# {'Here in Seattle ': ['A13',
#   'Harvest Moon',
#   'The Hillbillies',
#   'Hell N Back',
#   'Love$ick (feat. A$AP Rocky)',
#   'Delilah (pull me out of this)',
#   'DUKE',
#   'Tadow',
#   'MATHEMATICAL DISRESPECT',
#   'Misnomer',
#   'What Goes Around.../...Comes Around (Interlude)',
#   'Falling Apart',
#   'Givin’ Up (Not The One) (Don Toliver & 21 Savage, 2 Chainz)',
#   'Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, NAV, feat. A Boogie Wit da Hoodie)',
#   'Love, of Money',
#   'Spoiled Brat',
#   'MOON (feat. Herbie Hancock)',
#   'Charmander',
#   'Lamberghini',
#   'Yamaha',
#   'Me and Your Mama',
#   'Private Landing (feat. Justin Bieber & Future)',
#   'PENNYWISE',
#   'Self Love (Spider-Man: Across the Spider-Verse) (Metro Boomin & Coi Leray)',
#   "Don't Play That",
#   'Puff Daddy']}
